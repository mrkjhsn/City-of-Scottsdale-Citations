# %% [markdown]
# ### Which citations are most frequenly issued in combination with other citations?
#
# #### For this analysis I have narrowed the 'Citations' dataset to only those citations that have been issued to the same person, on the same day, where more than one citation was issued.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pyodbc
import pandas as pd
import seaborn as sns
import datetime
plt.rcParams["figure.figsize"] = [15, 7]
pd.set_option('display.max_columns', None)

# databaseConnection = 'DRIVER={SQL Server}; SERVER=ServerName; Database=DatbaseName; UID=UserId; PWD=password;'
connection = pyodbc.connect('DRIVER={SQL Server};SERVER=WINDOWS-A6S01I2\SQLEXPRESS;DATABASE=City_of_Scottsdale;Trusted_Connection=yes;')
cursor = connection.cursor()

# SQL query to import all citation data
citations = '''
select A.[Cited Person]
	,A.[Citation Type Description]
	,convert(varchar, A.[Citation Date], 101) as Citation_Date
	,A.[Charge Description]
	,concat(A.[Cited Person],A.[Cited Person Age]) as unique_identifier
	,B.count_of_citations
from [dbo].[spd_PDCitations$] as A
inner join (select [Cited Person]
			,[Cited Person Age]
			,[Citation Date]
			,concat([Cited Person],[Cited Person Age]) as unique_identifier
			,count(*) as count_of_citations
		   from [dbo].[spd_PDCitations$]
		   group by [Cited Person]
			,[Cited Person Age]
			,[Citation Date]
		   having count(*) >= '2'
		   ) as B on concat(A.[Cited Person],A.[Cited Person Age]) = B.unique_identifier
order by B.count_of_citations desc, A.[Cited Person], A.[Charge Description] 
  '''
multiple_citations = pd.read_sql(citations, connection)
connection.close()

multiple_citations.head(20)
# Out:
#            Cited Person Citation Type Description Citation_Date  \
# 0           Moore, Mark          Criminal Traffic    03/21/2018
# 1           Moore, Mark          Criminal Traffic    03/21/2018
# 2           Moore, Mark          Criminal Traffic    03/21/2018
# 3           Moore, Mark          Criminal Traffic    03/21/2018
# 4           Moore, Mark             Civil Traffic    03/21/2018
# 5           Moore, Mark          Criminal Traffic    09/02/2018
# 6     Berryhill, JOhnny                  Criminal    04/01/2018
# 7     Berryhill, JOhnny                  Criminal    04/01/2018
# 8     Berryhill, JOhnny                  Criminal    04/01/2018
# 9   Gonzales, Alejandro          Criminal Traffic    04/16/2018
# 10  Gonzales, Alejandro                  Criminal    04/16/2018
# 11  Gonzales, Alejandro             Civil Traffic    04/16/2018
# 12        Guzman, Simon          Criminal Traffic    01/13/2019
# 13        Guzman, Simon          Criminal Traffic    01/13/2019
# 14        Guzman, Simon          Criminal Traffic    01/13/2019
# 15        Laird, Gerald                  Criminal    01/29/2019
# 16        Laird, Gerald                  Criminal    01/29/2019
# 17        Laird, Gerald             Civil Traffic    01/29/2019
# 18        Leslie, Andre             Civil Traffic    10/30/2017
# 19        Leslie, Andre                  Criminal    10/30/2017
#
#                              Charge Description      unique_identifier  \
# 0               Exceed Limit By More Than 20mph          Moore, Mark35
# 1               Exceed Limit By More Than 20mph          Moore, Mark35
# 2               Exceed Limit By More Than 20mph          Moore, Mark35
# 3               Exceed Limit By More Than 20mph          Moore, Mark35
# 4              Speed Greater Than R&P or Posted          Moore, Mark35
# 5                        Suspended/Revoked D.L.          Moore, Mark35
# 6                Carry Deadly Wpn-Fail to Admit    Berryhill, JOhnny45
# 7            Criminal Nuisance-Endangers Others    Berryhill, JOhnny45
# 8                Drug Paraphernalia-Possess/Use    Berryhill, JOhnny45
# 9              DUI-Impaired to Slightest Degree  Gonzales, Alejandro35
# 10              False Report to Law Enforcement  Gonzales, Alejandro35
# 11                         Parking On Crosswalk  Gonzales, Alejandro35
# 12  Accidents - Fail to Give Info-Name Add Etc.        Guzman, Simon40
# 13                       Driving Left of Center        Guzman, Simon40
# 14                  Extreme DUI-BAC .15 or More        Guzman, Simon40
# 15             DUI-Impaired to Slightest Degree        Laird, Gerald39
# 16     Interfere W/Court Order-Viol Court Order        Laird, Gerald39
# 17                        No Proof of Insurance        Laird, Gerald39
# 18                       Driving Left of Center        Leslie, Andre32
# 19              False Report to Law Enforcement        Leslie, Andre32
#
#     count_of_citations
# 0                    5
# 1                    5
# 2                    5
# 3                    5
# 4                    5
# 5                    5
# 6                    3
# 7                    3
# 8                    3
# 9                    3
# 10                   3
# 11                   3
# 12                   3
# 13                   3
# 14                   3
# 15                   3
# 16                   3
# 17                   3
# 18                   3
# 19                   3
