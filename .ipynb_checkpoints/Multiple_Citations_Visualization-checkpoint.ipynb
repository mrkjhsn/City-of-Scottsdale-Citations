# %% [markdown]
# ## Which citations are most frequenly issued in combination with other citations?
#
# ### For this analysis I have narrowed the 'Citations' dataset to only those citations that have been issued to the same person, on the same day, where more than one citation was issued.  A total of 902 observations meet the above criteria.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pyodbc
import pandas as pd
import seaborn as sns
import datetime

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', -1)

# databaseConnection = 'DRIVER={SQL Server}; SERVER=ServerName; Database=DatbaseName; UID=UserId; PWD=password;'
connection = pyodbc.connect('DRIVER={SQL Server};SERVER=WINDOWS-A6S01I2\SQLEXPRESS;DATABASE=City_of_Scottsdale;Trusted_Connection=yes;')
cursor = connection.cursor()

# SQL query to import citations that have been issued to the same person, 
#on the same day, where more than one citation was issued
citations = '''
select *
from [dbo].[spd_PDCitations$] as A
inner join (select [Cited Person] as name2
			,[Cited Person Age] as age2
			,[Citation Date] as date2
			,concat([Cited Person],[Cited Person Age]) as unique_identifier
			,count(*) as count_of_citations
		   from [dbo].[spd_PDCitations$]
		   group by [Cited Person]
			,[Cited Person Age]
			,[Citation Date]
		   having count(*) >= '2'
		   ) as B on concat(A.[Cited Person],A.[Cited Person Age]) = B.unique_identifier
  '''
multiple_citations = pd.read_sql(citations, connection)
connection.close()

multiple_citations.head()
# Out:
#    tcmainid  Citation # Citation Date  Citation Time Arizona Statute Code  \
# 0  629619.0  8092148.0  2018-09-02     1909.0         4-251A2
# 1  629661.0  2065108.0  2018-09-03     208.0          28-1381A1
# 2  591099.0  2018203.0  2017-10-07     2237.0         28-1381A1
# 3  591100.0  2018204.0  2017-10-07     2237.0         13-2906A1
# 4  591104.0  2045406.0  2017-10-09     113.0          28-1381A1
#
#                                            Charge Description  \
# 0  Liquor-Possess Open Container In Vehicle
# 1  DUI-Impaired to Slightest Degree
# 2  DUI-Impaired to Slightest Degree
# 3  Reckless Interference-Obstruct Highway-Public Thoroughfare
# 4  DUI-Impaired to Slightest Degree
#
#   Citation Type Code Citation Type Description  Officer Badge # Street Number  \
# 0  CT                 Criminal Traffic          826.0            7xxx
# 1  CT                 Criminal Traffic          515.0            7xxx
# 2  CR                 Criminal                  1336.0            xxx
# 3  CR                 Criminal                  1336.0            xxx
# 4  CT                 Criminal Traffic          515.0            1xxx
#
#                                 Street        City State  Zip District  Beat  \
# 0  E Thomas Rd                          Scottsdale  AZ   NaN   D1       2.0
# 1  E Indian School Rd                   Scottsdale  AZ   NaN   D2       6.0
# 2  E Happy Valley Rd / N Scottsdale Rd  Scottsdale  AZ   NaN   D4       19.0
# 3  E Happy Valley Rd / N Scottsdale Rd  Scottsdale  AZ   NaN   D4       19.0
# 4  N Miller Rd                          Scottsdale  AZ   NaN   D1       3.0
#
#      Zone          Cited Person  Cited Person Age Cited Person Race  \
# 0  709.0   Hartman, Timothy      55.0              W
# 1  809.0   Lofthouse, Garret     21.0              W
# 2  4001.0  Abbott, JOy           57.0              W
# 3  4001.0  Abbott, JOy           57.0              W
# 4  406.0   Armenta-Garcia, Ever  24.0              W
#
#   Cited Person Sex Cited Person Ethnicity                 name2  age2  \
# 0  M                N                      Hartman, Timothy      55.0
# 1  M                N                      Lofthouse, Garret     21.0
# 2  F                N                      Abbott, JOy           57.0
# 3  F                N                      Abbott, JOy           57.0
# 4  M                H                      Armenta-Garcia, Ever  24.0
#
#        date2       unique_identifier  count_of_citations
# 0 2018-09-02  Hartman, Timothy55      2
# 1 2018-09-03  Lofthouse, Garret21     2
# 2 2017-10-07  Abbott, JOy57           2
# 3 2017-10-07  Abbott, JOy57           2
# 4 2017-10-09  Armenta-Garcia, Ever24  2

# %%
multiple_citations.shape
# Out:
# (902, 27)

# %%
# concatenates all the citations for each person into a string within one column on one row for each person
multiple_citations_concat = multiple_citations.groupby(['Cited Person'])['Charge Description'].apply(','.join).reset_index()

multiple_citations_concat.groupby(['Charge Description']).count().sort_values('Cited Person', ascending=False).head(10)

# this isn't correct since "DUI-Impaired to Slightest Degree,No Proof of Insurance" &
# "No Proof of Insurance,DUI-Impaired to Slightest Degree" are the same thing and should be grouped together
# a sort needs to take place within the citations for each person to ensure the above doesn't take place
# see below for solution
# Out:
#                                                                                 Cited Person
# Charge Description
# DUI-Impaired to Slightest Degree,No Proof of Insurance                          13
# Shoplifting-Removal of Goods,Shoplifting-Removal of Goods                       12
# DUI-Impaired to Slightest Degree,Fail to Drive In A Single Lane                 10
# DUI-Impaired to Slightest Degree,Improper Right Turn Method                     9
# DUI-Impaired to Slightest Degree,Failure to Control Speed to Avoid A Collision  8
# DUI-Impaired to Slightest Degree,Speed Greater Than R&P or Posted               8
# No Proof of Insurance,DUI-Impaired to Slightest Degree                          8
# DUI-Impaired to Slightest Degree,Driving In Bicycle Lane                        7
# Fail to Drive In A Single Lane,DUI-Impaired to Slightest Degree                 6
# Speed Greater Than R&P or Posted,DUI-Impaired to Slightest Degree               6

# %%
# creates list for each Cited Person
multiple_citations_concat['Split_Sort'] = multiple_citations_concat['Charge Description'].apply(lambda x: x.split(',')) 

# sorts citations within list of each person
multiple_citations_concat['Split_Sort'] = multiple_citations_concat['Split_Sort'].apply(lambda x: sorted(x))

# joins list of citations back together to be able to sort in final step
multiple_citations_concat['Split_Sort'] = multiple_citations_concat['Split_Sort'].apply(','.join)

multiple_citations_concat.head()
# Out:
#          Cited Person  \
# 0  Abbott, JOy
# 1  Acevedo, Jamie
# 2  Aguilar, Francina
# 3  Aiello, Jacqueline
# 4  Akmal, Jasmine
#
#                                                                                                              Charge Description  \
# 0  DUI-Impaired to Slightest Degree,Reckless Interference-Obstruct Highway-Public Thoroughfare,Speed Greater Than R&P or Posted
# 1  F/Obey Police Officer,DUI-Impaired to Slightest Degree
# 2  Release of Vehicle Violation,Suspended/Revoked D.L.
# 3  Prescription Drug-Possess/Use,DUI-Impaired to Slightest Degree
# 4  Disorderly Conduct-Disruptive Behavior,Urinate/Defecate In Public
#
#                                                                                                                      Split_Sort
# 0  DUI-Impaired to Slightest Degree,Reckless Interference-Obstruct Highway-Public Thoroughfare,Speed Greater Than R&P or Posted
# 1  DUI-Impaired to Slightest Degree,F/Obey Police Officer
# 2  Release of Vehicle Violation,Suspended/Revoked D.L.
# 3  DUI-Impaired to Slightest Degree,Prescription Drug-Possess/Use
# 4  Disorderly Conduct-Disruptive Behavior,Urinate/Defecate In Public

# %%
multiple_citations_ordered = multiple_citations_concat.groupby(['Split_Sort'])['Cited Person'] \
    .count() \
    .reset_index() \
    .sort_values('Cited Person', ascending=False) \

multiple_citations_ordered.head(20)
# Out:
#                                                                          Split_Sort  \
# 105  DUI-Impaired to Slightest Degree,No Proof of Insurance
# 84   DUI-Impaired to Slightest Degree,Fail to Drive In A Single Lane
# 114  DUI-Impaired to Slightest Degree,Speed Greater Than R&P or Posted
# 205  Shoplifting-Removal of Goods,Shoplifting-Removal of Goods
# 99   DUI-Impaired to Slightest Degree,Improper Right Turn Method
# 66   DUI-Impaired to Slightest Degree,Driving In Bicycle Lane
# 92   DUI-Impaired to Slightest Degree,Failure to Control Speed to Avoid A Collision
# 94   DUI-Impaired to Slightest Degree,False Report to Law Enforcement
# 98   DUI-Impaired to Slightest Degree,Improper Left Turn Method
# 89   DUI-Impaired to Slightest Degree,Fail to Stop For Red Signal
# 78   DUI-Impaired to Slightest Degree,Expired/No Arizona Registration
# 68   DUI-Impaired to Slightest Degree,Driving Without Lights at Night
# 71   DUI-Impaired to Slightest Degree,Drug Paraphernalia-Possess/Use
# 104  DUI-Impaired to Slightest Degree,No Arizona or M/C Driver`s License
# 82   DUI-Impaired to Slightest Degree,F/Obey Police Officer
# 77   DUI-Impaired to Slightest Degree,Exceed Limit By More Than 20mph
# 147  Drug Paraphernalia-Possess/Use,Liquor-Possess Open Container In Vehicle
# 67   DUI-Impaired to Slightest Degree,Driving Left of Center
# 102  DUI-Impaired to Slightest Degree,Liquor-Possess Open Container In Vehicle
# 141  Drug Paraphernalia-Possess/Use,Failure to Control Speed to Avoid A Collision
#
#      Cited Person
# 105  21
# 84   16
# 114  14
# 205  12
# 99   12
# 66   11
# 92   11
# 94   11
# 98   9
# 89   9
# 78   8
# 68   6
# 71   6
# 104  5
# 82   5
# 77   5
# 147  5
# 67   4
# 102  4
# 141  3

# %% [markdown]
# ### In most situations where multiple citations are issued a relatively minor infraction results in the person being pulled over, which creates the opportunity for assessment of a DUI citation.

# %%
ax = sns.barplot(x=multiple_citations_ordered.iloc[:,1].head(20), y=multiple_citations_ordered.iloc[:,0].head(20))

plt.xlabel("Count of People Who Received Citation Combination",fontsize=25)
plt.ylabel("Citation Combinations",fontsize=25)
plt.tick_params(labelsize=17)
